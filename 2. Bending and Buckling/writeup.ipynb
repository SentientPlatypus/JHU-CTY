# %% [markdown]
# # Materials lab
#
# > By Geneustace Wicaksono, Akul Mittal
#
# For this lab, we analyzed the buckling and bending for three different types of spaghetti. For Bending, We put each spaghetti between two tables, and added weight and measured displacement at each load. For buckling, we applied vertical force, and measured the length of the spaghetti and the force required for it to begin to bend.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math

# %% [markdown]
# ## Buckling
#
# Buckling force is measured as $$P = \frac{E\pi^3r^4}{4L^2}$$
#
# Where $E$ is Youngs modulus, $r$ is the raduius of the spaghetti, and $L$ is the length of the spaghetti

# %%
buckling = pd.read_csv("buckling.csv")

regular = buckling[buckling["type"] == "REGULAR"]
thin = buckling[buckling["type"] == "THIN"]
angel = buckling[buckling["type"] == "ANGEL HAIR"]
buckling
# Out:
#           type  Diameter (m)  Radius (m)  length (m)  buckling load (g)  \
# 0      REGULAR        0.0017     0.00085        0.25                 28
# 1      REGULAR        0.0017     0.00085        0.23                 33
# 2      REGULAR        0.0017     0.00085        0.21                 44
# 3      REGULAR        0.0017     0.00085        0.19                 54
# 4      REGULAR        0.0017     0.00085        0.17                 66
# 5      REGULAR        0.0017     0.00085        0.15                 86
# 6      REGULAR        0.0017     0.00085        0.13                128
# 7      REGULAR        0.0017     0.00085        0.11                192
# 8      REGULAR        0.0017     0.00085        0.09                264
# 9      REGULAR        0.0017     0.00085        0.07                400
# 10     REGULAR        0.0017     0.00085        0.05                612
# 11        THIN        0.0014     0.00070        0.25                 11
# 12        THIN        0.0014     0.00070        0.23                 14
# 13        THIN        0.0014     0.00070        0.21                 17
# 14        THIN        0.0014     0.00070        0.19                 22
# 15        THIN        0.0014     0.00070        0.17                 27
# 16        THIN        0.0014     0.00070        0.15                 30
# 17        THIN        0.0014     0.00070        0.13                 46
# 18        THIN        0.0014     0.00070        0.11                 69
# 19        THIN        0.0014     0.00070        0.09                140
# 20        THIN        0.0014     0.00070        0.07                204
# 21        THIN        0.0014     0.00070        0.05                281
# 22  ANGEL HAIR        0.0011     0.00055        0.25                  5
# 23  ANGEL HAIR        0.0011     0.00055        0.23                  6
# 24  ANGEL HAIR        0.0011     0.00055        0.21                  7
# 25  ANGEL HAIR        0.0011     0.00055        0.19                  9
# 26  ANGEL HAIR        0.0011     0.00055        0.17                 11
# 27  ANGEL HAIR        0.0011     0.00055        0.15                 17
# 28  ANGEL HAIR        0.0011     0.00055        0.13                 21
# 29  ANGEL HAIR        0.0011     0.00055        0.11                 36
# 30  ANGEL HAIR        0.0011     0.00055        0.09                 49
# 31  ANGEL HAIR        0.0011     0.00055        0.07                 71
# 32  ANGEL HAIR        0.0011     0.00055        0.05                138
#
#     buckling load (N)           E  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0            0.274586  4241246197         NaN         NaN         NaN
# 1            0.323620  4230824849         NaN         NaN         NaN
# 2            0.431493  4702693783         NaN         NaN         NaN
# 3            0.529559  4724505906         NaN         NaN         NaN
# 4            0.647239  4622715998         NaN         NaN         NaN
# 5            0.843372  4689606509         NaN         NaN         NaN
# 6            1.255251  5242665013         NaN         NaN         NaN
# 7            1.882877  5630436094         NaN         NaN         NaN
# 8            2.588956  5182560496         NaN         NaN         NaN
# 9            3.922661  4750195741         NaN         NaN         NaN
# 10           6.001671  3708060961         NaN         NaN         NaN
# 11           0.107873  3622527406         NaN         NaN         NaN
# 12           0.137293  3902318251         NaN         NaN         NaN
# 13           0.166713  3950267341         NaN         NaN         NaN
# 14           0.215746  4184743660         NaN         NaN         NaN
# 15           0.264780  4111502742         NaN         NaN         NaN
# 16           0.294200  3556663272         NaN         NaN         NaN
# 17           0.451106  4096222263         NaN         NaN         NaN
# 18           0.676659  4399197282         NaN         NaN         NaN
# 19           1.372931  5975194297         NaN         NaN         NaN
# 20           2.000557  5267023121         NaN         NaN         NaN
# 21           2.755669  3701564368         NaN         NaN         NaN
# 22           0.049033  4320464103         NaN         NaN         NaN
# 23           0.058840  4388208980         NaN         NaN         NaN
# 24           0.068647  4267927259         NaN         NaN         NaN
# 25           0.088260  4491900118         NaN         NaN         NaN
# 26           0.107873  4395121723         NaN         NaN         NaN
# 27           0.166713  5288248062         NaN         NaN         NaN
# 28           0.205940  4906664672         NaN         NaN         NaN
# 29           0.353039  6022381322         NaN         NaN         NaN
# 30           0.480526  5487335048         NaN         NaN         NaN
# 31           0.696272  4809886276         NaN         NaN         NaN
# 32           1.353318  4769792370         NaN         NaN         NaN
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25          NaN          NaN          NaN          NaN          NaN
# 26          NaN          NaN          NaN          NaN          NaN
# 27          NaN          NaN          NaN          NaN          NaN
# 28          NaN          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN          NaN
# 30          NaN          NaN          NaN          NaN          NaN
# 31          NaN          NaN          NaN          NaN          NaN
# 32          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 15
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN

# %% [markdown]
# We want to see the relationship between length of the spaghetti and the buckling load.

# %%
line_colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown']
labelnames = ["regular", "thin", "angel hair"]
labels = [regular, thin, angel]
for i in range(len(labels)):
    plt.plot(labels[i]["length (m)"], labels[i]["buckling load (N)"], color = line_colors[i], label = labelnames[i])

plt.title("Buckling load as a function of length")

plt.xlabel("Length of spaghetti")
plt.ylabel("Bucking load (N)")

plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# We see that this relationship is similar to that of an inverse function is dilated by constant $k$, where $$k = \frac{E\pi^3r^4}{4}$$ <br>
#
# rewriting the equation for buckling load, we get
# $$P = \frac{k}{L^2} $$
#
# We can linearlize this by taking the $\ln$ of $P$ and $L$ <br>
# $$\ln P = \ln \left(\frac{k}{L^2}\right)$$
# $$\ln P = \ln k - \ln \left(L^2\right)$$
# $$\ln P = \ln k - 2\ln L \rightarrow E = \frac {4 e^{\ln k}}{\pi ^3 r^4}$$

# %%
for i in range(len(labels)):
    x = labels[i]["length (m)"].apply(np.log)  # X-axis data
    y = labels[i]["buckling load (N)"].apply(np.log)  # Y-axis data

    # Perform linear regression (fit a polynomial line of degree 1)
    coeffs = np.polyfit(x, y, deg=1)

    # Extract the slope and intercept from the coefficients
    slope = coeffs[0]
    intercept = coeffs[1]

    # Create the equation string
    equation = f"ln yhat = {slope:.2f} * ln x + {intercept:.2f}"
    young_modulus = (math.exp(intercept) * 4) / (math.pi**3 * labels[i]["Radius (m)"].iloc[0]**4)

    # Print the equation for the label type
    print(f"Label Type: {labelnames[i]}")
    print("Radius: ", labels[i]["Radius (m)"].iloc[0])
    print("Equation:", equation)
    print(f"Young Modulus: {young_modulus:.2e}")
    print()

    # Plot the data points and the fitted line
    plt.scatter(x, y, color=line_colors[i], label=labelnames[i])
    plt.plot(x, np.polyval(coeffs, x), '--', color=line_colors[i])

# Set plot title and labels
plt.title("Buckling load as a function of length")
plt.xlabel("natural log of Length of spaghetti")
plt.ylabel("natural log Buckling load (N)")

# Display the legend
plt.legend()

# Display the plot
plt.show()
# Out:
# Label Type: regular
# Radius:  0.00085
# Equation: ln yhat = -1.99 * ln x + -3.95
# Young Modulus: 4.77e+09
#
# Label Type: thin
# Radius:  0.0007
# Equation: ln yhat = -2.13 * ln x + -5.12
# Young Modulus: 3.21e+09
#
# Label Type: angel hair
# Radius:  0.00055
# Equation: ln yhat = -2.11 * ln x + -5.90
# Young Modulus: 3.85e+09

# %% [markdown]
# ## Bending
# Bending is represented as :
# $$P = \frac{12\pi E r^4 y}{L^3}$$
# Where $P$ is bending load, $E$ is youngs modulus, $r$ is spaghetti radius, $y$ is deflection$ and $L$ is distance between supports
#
# Like buckling, we can put this in terms of constant $k$ where
# $$k = \frac{12\pi E r^4}{L^3} \rightarrow E = \frac {kL^3} {12\pi r^4}$$
# so,
# $$P = ky$$

# %%
bending = pd.read_csv("bending.csv")
print(bending.columns)
bending = bending.drop(['notes'], axis=1)
bending.dropna(inplace=True)
regular = bending[bending["type"] == "REGULAR"]
thin = bending[bending["type"] == "THIN"]
angel = bending[bending["type"] == "ANGEL HAIR"]
bending
# Out:
# Index(['type', 'Diameter (m)', 'Radius (m)', 'length (m)', 'bending load (g)',
#        'bending load (N)', 'E', 'Deflection (m)', 'notes'],
#       dtype='object')
#           type  Diameter (m)  Radius (m)  length (m)  bending load (g)  \
# 0      REGULAR        0.0017     0.00085       0.153              11.0
# 1      REGULAR        0.0017     0.00085       0.153              15.0
# 2      REGULAR        0.0017     0.00085       0.153              19.0
# 3      REGULAR        0.0017     0.00085       0.153              23.0
# 4      REGULAR        0.0017     0.00085       0.153              28.0
# 5      REGULAR        0.0017     0.00085       0.153              32.0
# 6      REGULAR        0.0017     0.00085       0.153              36.0
# 7      REGULAR        0.0017     0.00085       0.153              40.0
# 12        THIN        0.0014     0.00070       0.153              11.0
# 13        THIN        0.0014     0.00070       0.153              16.0
# 14        THIN        0.0014     0.00070       0.153              19.0
# 15        THIN        0.0014     0.00070       0.153              23.0
# 16        THIN        0.0014     0.00070       0.153              24.0
# 17        THIN        0.0014     0.00070       0.153              25.0
# 18        THIN        0.0014     0.00070       0.153              26.0
# 24  ANGEL HAIR        0.0011     0.00055       0.153              11.0
# 25  ANGEL HAIR        0.0011     0.00055       0.153              12.0
#
#     bending load (N)           E  Deflection (m)
# 0           0.107873  2181415581           0.009
# 1           0.147100  2677191849           0.010
# 2           0.186326  2825924729           0.012
# 3           0.225553  2736685001           0.015
# 4           0.274586  2939661638           0.017
# 5           0.313813  2855671305           0.020
# 6           0.353039  2793591494           0.023
# 7           0.392266  2461785608           0.029
# 12          0.107873  3556994690           0.012
# 13          0.156906  3652101500           0.017
# 14          0.186326  3510799954           0.021
# 15          0.225553  2974941014           0.030
# 16          0.235360  2910268383           0.032
# 17          0.245166  2771684174           0.035
# 18          0.254973  1834350981           0.055
# 24          0.107873  3499902022           0.032
# 25          0.117680  2349584575           0.052

# %% [markdown]
# Lets observe the relationship between load and deflection:

# %%
line_colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown']
labelnames = ["regular", "thin", "angel hair"]
labels = [regular, thin, angel]


for i in range(len(labels)):
    x = labels[i]["bending load (N)"] # X-axis data
    y = labels[i]["Deflection (m)"] # Y-axis data

    # Perform linear regression (fit a polynomial line of degree 1)
    coeffs = np.polyfit(x, y, deg=1)

    # Extract the slope and intercept from the coefficients
    slope = coeffs[0]
    intercept = coeffs[1]

    # Create the equation string
    equation = f"yhat = {slope:.2f} * x + {intercept:.2f}"
    young_modulus = (slope * labels[i]["length (m)"].iloc[0] ** 3) / (12 * math.pi * labels[i]["Radius (m)"].iloc[0] ** 4)

    # Print the equation for the label type
    print(f"Label Type: {labelnames[i]}")
    print("Radius: ", labels[i]["Radius (m)"].iloc[0])
    print("Distance in supports: ", labels[i]["length (m)"].iloc[0])
    print("Equation:", equation)
    print(f"Young Modulus: {young_modulus:.2e}")
    print()

    # Plot the data points and the fitted line
    plt.scatter(x, y, color=line_colors[i], label=labelnames[i])
    plt.plot(x, np.polyval(coeffs, x), '--', color=line_colors[i])

# for i in range(len(labels)):
#     plt.plot(labels[i]["bending load (N)"], labels[i]["Deflection (m)"], color = line_colors[i], label = labelnames[i])

plt.title("Deflection load as a function of load")

plt.xlabel("Bending load (N)")
plt.ylabel("Deflection (m)")

plt.legend()

# Display the plot
plt.show()
# Out:
# Label Type: regular
# Radius:  0.00085
# Distance in supports:  0.153
# Equation: yhat = 0.07 * x + 0.00
# Young Modulus: 1.22e+07
#
# Label Type: thin
# Radius:  0.0007
# Distance in supports:  0.153
# Equation: yhat = 0.23 * x + -0.02
# Young Modulus: 9.12e+07
#
# Label Type: angel hair
# Radius:  0.00055
# Distance in supports:  0.153
# Equation: yhat = 2.04 * x + -0.19
# Young Modulus: 2.12e+09

# %% [markdown]
# $$$$
